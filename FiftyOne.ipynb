# %% [markdown]
# <a href="https://colab.research.google.com/github/johnnyshorten/Aquatutor/blob/main/FiftyOne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# AquaTutor
# Notebook: 01_Environment_Setup.ipynb
#
# Purpose:
# Configure and run FiftyOne
#
# Author:
# John Shorten
#
# Version:
# 0.1
# =============================================================================

# %%
# 1. Force down a stable Pillow version and quiet the output
# !pip install --upgrade "Pillow<11.0.0" fiftyone --quiet

# 2. Hard reset the active Python environment to load it cleanly
import os
os.kill(os.getpid(), 9)

# %%
# Run FiftyOne in a seperate browser

import fiftyone as fo
import fiftyone.zoo as foz

# 1. Load the dataset
dataset = foz.load_zoo_dataset("quickstart", max_samples=100)

# 2. Launch with auto=False to stop the state synchronization loop
session = fo.launch_app(dataset, auto=False)

# 3. Open the tab manually
session.open_tab()
# Out:
# Dataset already downloaded
# INFO:fiftyone.zoo.datasets:Dataset already downloaded
# Loading existing dataset 'quickstart-100'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# INFO:fiftyone.zoo.datasets:Loading existing dataset 'quickstart-100'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# Session launched. Run `session.show()` to open the App in a cell output.
# INFO:fiftyone.core.session.session:Session launched. Run `session.show()` to open the App in a cell output.

# %%
# set up git
# !git clone https://github.com/johnnyshorten/Aquatutor.git
# %cd Aquatutor
# Out:
# Cloning into 'Aquatutor'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 12.49 MiB | 19.03 MiB/s, done.
# /content/Aquatutor

# %%
# create folder structor
import os

folders = [
    "docs",
    "notebooks",
    "datasets",
    "models",
    "results",
    "figures",
    "experiments",
    "journal",
    "scripts",
    "src",
    "reports",
    "presentations",
    "assets"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("AquaTutor folders created")
# Out:
# AquaTutor folders created

# %%
# test folders created
# !find . -maxdepth 2 -type d
# Out:
# .
# ./.git
# ./.git/refs
# ./.git/hooks
# ./.git/objects
# ./.git/branches
# ./.git/info
# ./.git/logs
# ./experiments
# ./presentations
# ./notebooks
# ./reports
# ./models
# ./docs
# ./datasets
# ./scripts
# ./journal
# ./assets
# ./results
# ./src
# ./figures
