# %% [markdown]
# <a href="https://colab.research.google.com/github/johnnyshorten/Aquatutor/blob/main/notebooks/01_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# AquaTutor
# Notebook: 01_Environment_Setup.ipynb
# Purpose: Install packages and prepare the Colab runtime
# =============================================================================

# %%
# Import packages
import os
import fiftyone as fo
import fiftyone.zoo as foz
import ultralytics
import torch

# %%
# Versions
PROJECT_VERSION = "v0.2.0"
CURRENT_SPRINT = "Sprint 2"

# %%
# Create Repo

if not os.path.exists("/content/Aquatutor"):
    # !git clone https://github.com/johnnyshorten/Aquatutor.git

# %cd /content/Aquatutor


# Verify the project structure
# !find . -maxdepth 2 -type d

# %%
# Check GPU
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")

# %%
# check Versions

print("FiftyOne:", fiftyone.__version__)
print("Ultralytics:", ultralytics.__version__)

# %%
# Smoke Test
dataset = foz.load_zoo_dataset("quickstart", max_samples=100)
session = fo.launch_app(dataset, auto=False)
session.open_tab()

# %%
# =============================================================================
# AquaTutor Environment Status
# =============================================================================


try:
    import torch
    gpu_available = torch.cuda.is_available()
    gpu_name = torch.cuda.get_device_name(0) if gpu_available else "CPU Only"
except:
    gpu_available = False
    gpu_name = "Unknown"

print("=" * 60)
print("🐟 AquaTutor Environment Status")
print("=" * 60)

print(f"Project            : AquaTutor")
print(f"Sprint             : 2")
print(f"Notebook           : 02_Run_Environment.ipynb")
print()

print(f"Python Version     : {platform.python_version()}")
print(f"Operating System   : {platform.system()} {platform.release()}")
print()

print(f"GPU Available      : {'✅ YES' if gpu_available else '❌ NO'}")
print(f"GPU                : {gpu_name}")
print()

print(f"FiftyOne Version   : {fiftyone.__version__}")
print(f"Ultralytics        : {ultralytics.__version__}")
print()

print(f"Working Directory  : {os.getcwd()}")
print(f"Python Executable  : {sys.executable}")

print("=" * 60)
print("✅ Environment Ready")
print("Next Notebook: 03_Dataset_Selection.ipynb")
print("=" * 60)
